# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryansalamahu56/362220002-tugas-ryansalamahu/blob/main/Tugas_2_crime_36220002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
# Import library untuk analisis data
import pandas as pd  # Library untuk manipulasi data berbasis tabel (DataFrame)
import numpy as np  # Library untuk operasi numerik dan array multidimensional

# Import library untuk visualisasi data
import matplotlib.pyplot as plt  # Library untuk membuat plot dan grafik dasar
import seaborn as sns  # Library untuk visualisasi data yang lebih canggih berbasis matplotlib

# Import library untuk memperingatkan jika ada potensi kesalahan
import warnings  # Mengatur pesan peringatan
warnings.filterwarnings('ignore')  # Menonaktifkan semua pesan peringatan

# Membaca dataset ke dalam dataframe Pandas
file_path = '/content/Crime_Data_from_2020_to_Present.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# # **Preview Dataset**

# %%
# Menampilkan 5 baris pertama dari dataset untuk memahami struktur data
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
# Menampilkan 10 baris pertama dari dataset
df.head(10)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
# 5  231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300    18
# 6  230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900     1
# 7  220314085  07/22/2022 12:00:00 AM  05/12/2020 12:00:00 AM      1110     3
# 8  231309864  04/28/2023 12:00:00 AM  12/09/2020 12:00:00 AM      1400    13
# 9  211904005  12/31/2020 12:00:00 AM  12/31/2020 12:00:00 AM      1220    19
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# ...

# %%
# Menampilkan 10 baris terakhir dari dataset
df.tail(10)
# Out:
#            DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 32729  201517145  10/19/2020 12:00:00 AM  10/07/2020 12:00:00 AM       940
# 32730  200615864  09/25/2020 12:00:00 AM  08/25/2020 12:00:00 AM      1000
# 32731  211007588  05/02/2021 12:00:00 AM  03/01/2020 12:00:00 AM         1
# 32732  200906860  03/03/2020 12:00:00 AM  03/02/2020 12:00:00 AM      1630
# 32733  201710655  06/29/2020 12:00:00 AM  06/29/2020 12:00:00 AM         1
# 32734  201609568  05/30/2020 12:00:00 AM  05/29/2020 12:00:00 AM         1
# 32735  201405209  01/21/2020 12:00:00 AM  01/21/2020 12:00:00 AM       550
# 32736  200904486  01/12/2020 12:00:00 AM  01/11/2020 12:00:00 AM      2000
# 32737  200122169  12/09/2020 12:00:00 AM  12/09/2020 12:00:00 AM      2235
# 32738  200409738  06/12/2020 12:00:00 AM  06/12/2020 12:00:00 AM       900
#
#        AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 32729    15  N Hollywood         1557         1     480
# ...

# %% [markdown]
# # **Data Information**

# %%
# Menampilkan informasi umum tentang dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32739 entries, 0 to 32738
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DR_NO           32739 non-null  int64
#  1   Date Rptd       32739 non-null  object
#  2   DATE OCC        32739 non-null  object
#  3   TIME OCC        32739 non-null  int64
#  4   AREA            32739 non-null  int64
#  5   AREA NAME       32739 non-null  object
#  6   Rpt Dist No     32739 non-null  int64
#  7   Part 1-2        32739 non-null  int64
#  8   Crm Cd          32739 non-null  int64
#  9   Crm Cd Desc     32739 non-null  object
#  10  Mocodes         28317 non-null  object
#  11  Vict Age        32739 non-null  int64
#  12  Vict Sex        28564 non-null  object
#  13  Vict Descent    28562 non-null  object
#  14  Premis Cd       32738 non-null  float64
#  15  Premis Desc     32725 non-null  object
#  16  Weapon Used Cd  11731 non-null  float64
# ...

# %%
# Menampilkan jumlah kolom dalam dataset
num_columns = df.shape[1]
print(f"Jumlah kolom: {num_columns}")
# Out:
# Jumlah kolom: 28

# %%
# Menampilkan nama-nama kolom dalam dataset
column_names = df.columns
print("Nama kolom dalam dataset:")
print(column_names)
# Out:
# Nama kolom dalam dataset:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
# Menampilkan jumlah total data (baris) dalam dataset
num_rows = df.shape[0]
print(f"Jumlah total data (baris): {num_rows}")
# Out:
# Jumlah total data (baris): 32739

# %%
# Menampilkan jumlah total data (baris) dalam dataset
num_rows = len(df)
print(f"Jumlah total data (baris): {num_rows}")
# Out:
# Jumlah total data (baris): 32739

# %% [markdown]
# # **Check Missing Values**

# %%
# Menghitung jumlah nilai yang hilang (missing values) di setiap kolom
missing_values = df.isnull().sum()

# Menampilkan jumlah nilai yang hilang per kolom
print("Jumlah nilai yang hilang per kolom:")
print(missing_values)
# Out:
# Jumlah nilai yang hilang per kolom:
# DR_NO                 0
# Date Rptd             0
# DATE OCC              0
# TIME OCC              0
# AREA                  0
# AREA NAME             0
# Rpt Dist No           0
# Part 1-2              0
# Crm Cd                0
# Crm Cd Desc           0
# Mocodes            4422
# Vict Age              0
# Vict Sex           4175
# Vict Descent       4177
# Premis Cd             1
# Premis Desc          14
# Weapon Used Cd    21008
# Weapon Desc       21008
# Status                0
# Status Desc           0
# Crm Cd 1              1
# Crm Cd 2          30053
# Crm Cd 3          32656
# Crm Cd 4          32736
# LOCATION              0
# Cross Street      27189
# LAT                   0
# LON                   1
# dtype: int64

# %%
# Menampilkan jumlah missing values sebelum imputasi
print("Jumlah nilai yang hilang per kolom sebelum imputasi:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang per kolom sebelum imputasi:
# DR_NO                 0
# Date Rptd             0
# DATE OCC              0
# TIME OCC              0
# AREA                  0
# AREA NAME             0
# Rpt Dist No           0
# Part 1-2              0
# Crm Cd                0
# Crm Cd Desc           0
# Mocodes            4422
# Vict Age              0
# Vict Sex           4175
# Vict Descent       4177
# Premis Cd             1
# Premis Desc          14
# Weapon Used Cd    21008
# Weapon Desc       21008
# Status                0
# Status Desc           0
# Crm Cd 1              1
# Crm Cd 2          30053
# Crm Cd 3          32656
# Crm Cd 4          32736
# LOCATION              0
# Cross Street      27189
# LAT                   0
# LON                   1
# dtype: int64

# %%
# Mengisi missing values pada kolom numerik dengan median
df['Premis Cd'] = df['Premis Cd'].fillna(df['Premis Cd'].median())  # Mengisi dengan median untuk kolom numerik

# Mengisi missing values pada kolom kategorikal dengan modus
df['Vict Sex'] = df['Vict Sex'].fillna(df['Vict Sex'].mode()[0])  # Mengisi dengan modus untuk kolom kategorikal
df['Vict Descent'] = df['Vict Descent'].fillna(df['Vict Descent'].mode()[0])  # Mengisi dengan modus untuk kolom kategorikal
df['Crm Cd 1'] = df['Crm Cd 1'].fillna(df['Crm Cd 1'].mode()[0])  # Mengisi dengan modus untuk kolom kategorikal

# Mengisi missing values pada kolom numerik menggunakan interpolasi
df['LAT'] = df['LAT'].interpolate()  # Mengisi dengan interpolasi untuk kolom numerik
df['LON'] = df['LON'].interpolate()  # Mengisi dengan interpolasi untuk kolom numerik

# Mengisi missing values pada kolom kategorikal dengan nilai tetap
df['Weapon Used Cd'] = df['Weapon Used Cd'].fillna('Unknown')  # Mengisi dengan nilai tetap untuk kolom kategorikal

# %%
# Mengisi missing values dengan modus atau nilai tetap
df['Premis Desc'] = df['Premis Desc'].fillna(df['Premis Desc'].mode()[0])
df['Weapon Desc'] = df['Weapon Desc'].fillna(df['Weapon Desc'].mode()[0])
df['Crm Cd 2'] = df['Crm Cd 2'].fillna(df['Crm Cd 2'].mode()[0])
df['Crm Cd 3'] = df['Crm Cd 3'].fillna(df['Crm Cd 3'].mode()[0])
df['Crm Cd 4'] = df['Crm Cd 4'].fillna(df['Crm Cd 4'].mode()[0])
df['Cross Street'] = df['Cross Street'].fillna(df['Cross Street'].mode()[0])

# %%
# Kolom yang dianggap sebagai data numerik (jika memang numerik)
numeric_columns = ['Mocodes', 'Premis Desc', 'Weapon Desc', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Cross Street']

# Kolom yang dianggap sebagai data kategorikal
categorical_columns = ['Vict Sex', 'Vict Descent', 'Weapon Used Cd', 'Crm Cd 1']

# %%
# Mengisi missing values pada kolom kategorikal dengan modus
for col in categorical_columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# Mengisi missing values pada kolom kategorikal dengan nilai tetap (jika ada)
df['Weapon Used Cd'] = df['Weapon Used Cd'].fillna('Unknown')

# %%
# Menampilkan jumlah nilai yang hilang per kolom setelah imputasi
missing_values_after_additional = df.isnull().sum()
print("Jumlah nilai yang hilang per kolom setelah imputasi tambahan:")
print(missing_values_after_additional)
# Out:
# Jumlah nilai yang hilang per kolom setelah imputasi tambahan:
# DR_NO                0
# Date Rptd            0
# DATE OCC             0
# TIME OCC             0
# AREA                 0
# AREA NAME            0
# Rpt Dist No          0
# Part 1-2             0
# Crm Cd               0
# Crm Cd Desc          0
# Mocodes           4422
# Vict Age             0
# Vict Sex             0
# Vict Descent         0
# Premis Cd            0
# Premis Desc          0
# Weapon Used Cd       0
# Weapon Desc          0
# Status               0
# Status Desc          0
# Crm Cd 1             0
# Crm Cd 2             0
# Crm Cd 3             0
# Crm Cd 4             0
# LOCATION             0
# Cross Street         0
# LAT                  0
# LON                  0
# dtype: int64

# %%
# Mengisi missing value di kolom 'Status' dengan nilai yang sesuai (misalnya modus atau nilai tetap)
df['Status'] = df['Status'].fillna(df['Status'].mode()[0])

# %%
# Cek tipe data kolom 'Mocodes'
print(df['Mocodes'].dtype)

# Jika 'Mocodes' bukan numerik, coba ubah atau tangani data
df['Mocodes'] = pd.to_numeric(df['Mocodes'], errors='coerce')  # Ubah menjadi numerik, set data yang tidak valid menjadi NaN

# Imputasi ulang dengan median setelah memastikan tipe data
df['Mocodes'] = df['Mocodes'].fillna(df['Mocodes'].median())
# Out:
# object

# %%
# Menampilkan jumlah nilai yang hilang per kolom setelah imputasi tambahan
missing_values_after_final = df.isnull().sum()
print("Jumlah nilai yang hilang per kolom setelah imputasi final:")
print(missing_values_after_final)
# Out:
# Jumlah nilai yang hilang per kolom setelah imputasi final:
# DR_NO             0
# Date Rptd         0
# DATE OCC          0
# TIME OCC          0
# AREA              0
# AREA NAME         0
# Rpt Dist No       0
# Part 1-2          0
# Crm Cd            0
# Crm Cd Desc       0
# Mocodes           0
# Vict Age          0
# Vict Sex          0
# Vict Descent      0
# Premis Cd         0
# Premis Desc       0
# Weapon Used Cd    0
# Weapon Desc       0
# Status            0
# Status Desc       0
# Crm Cd 1          0
# Crm Cd 2          0
# Crm Cd 3          0
# Crm Cd 4          0
# LOCATION          0
# Cross Street      0
# LAT               0
# LON               0
# dtype: int64

# %%
# Menampilkan informasi umum tentang dataset setelah imputasi
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32739 entries, 0 to 32738
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DR_NO           32739 non-null  int64
#  1   Date Rptd       32739 non-null  object
#  2   DATE OCC        32739 non-null  object
#  3   TIME OCC        32739 non-null  int64
#  4   AREA            32739 non-null  int64
#  5   AREA NAME       32739 non-null  object
#  6   Rpt Dist No     32739 non-null  int64
#  7   Part 1-2        32739 non-null  int64
#  8   Crm Cd          32739 non-null  int64
#  9   Crm Cd Desc     32739 non-null  object
#  10  Mocodes         32739 non-null  float64
#  11  Vict Age        32739 non-null  int64
#  12  Vict Sex        32739 non-null  object
#  13  Vict Descent    32739 non-null  object
#  14  Premis Cd       32739 non-null  float64
#  15  Premis Desc     32739 non-null  object
#  16  Weapon Used Cd  32739 non-null  object
# ...

# %%
# Menampilkan 10 baris pertama dari dataset yang telah dibersihkan
df.head(10)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
# 5  231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300    18
# 6  230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900     1
# 7  220314085  07/22/2022 12:00:00 AM  05/12/2020 12:00:00 AM      1110     3
# 8  231309864  04/28/2023 12:00:00 AM  12/09/2020 12:00:00 AM      1400    13
# 9  211904005  12/31/2020 12:00:00 AM  12/31/2020 12:00:00 AM      1220    19
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# ...

# %% [markdown]
# # **Statistical Summary**

# %%
# Statistik deskriptif untuk kolom numerik
print("Statistik deskriptif:")
print(df.describe())
# Out:
# Statistik deskriptif:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  3.273900e+04  32739.000000  32739.000000  32739.000000  32739.000000
# mean   2.026426e+08   1346.218547     10.834509   1129.464584      1.433061
# std    5.682336e+06    647.271633      6.015638    601.585665      0.495507
# min    1.903265e+08      1.000000      1.000000    101.000000      1.000000
# 25%    2.006132e+08    920.000000      6.000000    636.000000      1.000000
# 50%    2.012140e+08   1420.000000     11.000000   1151.000000      1.000000
# 75%    2.018046e+08   1900.000000     16.000000   1622.000000      2.000000
# max    2.420047e+08   2359.000000     21.000000   2198.000000      2.000000
#
#              Crm Cd       Mocodes      Vict Age     Premis Cd      Crm Cd 1  \
# count  32739.000000  32739.000000  32739.000000  32739.000000  32739.000000
# mean     508.214301    394.649073     29.964965    303.397630    507.868933
# ...

# %%
# Statistik deskriptif untuk kolom kategorikal
print("\nStatistik Deskriptif untuk Kolom Kategorikal:")
for col in df.select_dtypes(include=['object']).columns:
    print(f"\nFrekuensi untuk kolom {col}:")
    print(df[col].value_counts())
# Out:
# Statistik Deskriptif untuk Kolom Kategorikal:
#
# Frekuensi untuk kolom Date Rptd:
# Date Rptd
# 06/10/2020 12:00:00 AM    125
# 06/29/2020 12:00:00 AM    114
# 07/13/2020 12:00:00 AM    111
# 10/09/2020 12:00:00 AM    111
# 06/25/2020 12:00:00 AM    111
#                          ...
# 11/11/2023 12:00:00 AM      1
# 09/28/2023 12:00:00 AM      1
# 04/24/2022 12:00:00 AM      1
# 01/27/2023 12:00:00 AM      1
# 05/02/2021 12:00:00 AM      1
# Name: count, Length: 1237, dtype: int64
#
# Frekuensi untuk kolom DATE OCC:
# DATE OCC
# 01/01/2020 12:00:00 AM    316
# 06/01/2020 12:00:00 AM    174
# 03/01/2020 12:00:00 AM    158
# 05/30/2020 12:00:00 AM    158
# 12/01/2020 12:00:00 AM    147
#                          ...
# 10/19/2020 12:00:00 AM     63
# 03/29/2020 12:00:00 AM     63
# 04/04/2020 12:00:00 AM     61
# 09/24/2020 12:00:00 AM     61
# 03/19/2020 12:00:00 AM     55
# Name: count, Length: 366, dtype: int64
#
# Frekuensi untuk kolom AREA NAME:
# AREA NAME
# 77th Street    2211
# ...

# %%
# Nilai unik dan frekuensi untuk kolom tertentu, misalnya 'Vict Sex'
print("\nNilai Unik dan Frekuensi untuk Kolom 'Vict Sex':")
print(df['Vict Sex'].value_counts())
# Out:
# Nilai Unik dan Frekuensi untuk Kolom 'Vict Sex':
# Vict Sex
# M    17924
# F    12107
# X     2705
# H        3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Histogram untuk kolom numerik 'Vict Age'
plt.figure(figsize=(10, 6))
df['Vict Age'].hist(bins=30)
plt.title('Distribusi Umur Korban')
plt.xlabel('Umur')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Statistik keterangan tambahan
print("\nStatistik Keterangan Tambahan untuk Kolom Numerik:")
for col in df.select_dtypes(include=['number']).columns:
    print(f"\nKolom {col}:")
    print(f"Median: {df[col].median()}")
    print(f"Modus: {df[col].mode()[0]}")
    print(f"Standar Deviasi: {df[col].std()}")
# Out:
# Statistik Keterangan Tambahan untuk Kolom Numerik:
#
# Kolom DR_NO:
# Median: 201213962.0
# Modus: 190326475
# Standar Deviasi: 5682335.646693826
#
# Kolom TIME OCC:
# Median: 1420.0
# Modus: 1200
# Standar Deviasi: 647.2716325886965
#
# Kolom AREA:
# Median: 11.0
# Modus: 12
# Standar Deviasi: 6.015637703673106
#
# Kolom Rpt Dist No:
# Median: 1151.0
# Modus: 162
# Standar Deviasi: 601.5856649621911
#
# Kolom Part 1-2:
# Median: 1.0
# Modus: 1
# Standar Deviasi: 0.49550654375315323
#
# Kolom Crm Cd:
# Median: 480.0
# Modus: 510
# Standar Deviasi: 209.7445314637848
#
# Kolom Mocodes:
# Median: 344.0
# Modus: 344.0
# Standar Deviasi: 272.7509880989076
#
# Kolom Vict Age:
# Median: 31.0
# Modus: 0
# Standar Deviasi: 21.796975848164593
#
# Kolom Premis Cd:
# Median: 203.0
# Modus: 101.0
# Standar Deviasi: 213.57697685600172
#
# Kolom Crm Cd 1:
# Median: 480.0
# Modus: 510.0
# Standar Deviasi: 209.47573348405453
#
# Kolom Crm Cd 2:
# Median: 998.0
# Modus: 998.0
# ...

# %%
# Memilih hanya kolom numerik untuk analisis korelasi
numeric_columns = df.select_dtypes(include=['number']).columns
print("Kolom Numerik yang Tersedia untuk Korelasi:")
print(numeric_columns)
# Out:
# Kolom Numerik yang Tersedia untuk Korelasi:
# Index(['DR_NO', 'TIME OCC', 'AREA', 'Rpt Dist No', 'Part 1-2', 'Crm Cd',
#        'Mocodes', 'Vict Age', 'Premis Cd', 'Crm Cd 1', 'Crm Cd 2', 'Crm Cd 3',
#        'Crm Cd 4', 'LAT', 'LON'],
#       dtype='object')

# %%
# Mengubah kolom yang seharusnya numerik menjadi numerik
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
# Matriks Korelasi
correlation_matrix = df[numeric_columns].corr()
print("\nMatriks Korelasi antara Kolom Numerik:")
print(correlation_matrix)
# Out:
# Matriks Korelasi antara Kolom Numerik:
#                 DR_NO  TIME OCC      AREA  Rpt Dist No  Part 1-2    Crm Cd  \
# DR_NO        1.000000 -0.077961  0.131616     0.131395  0.171346 -0.049367
# TIME OCC    -0.077961  1.000000  0.010987     0.010964 -0.040490  0.004699
# AREA         0.131616  0.010987  1.000000     0.999018 -0.000663 -0.009071
# Rpt Dist No  0.131395  0.010964  0.999018     1.000000 -0.000467 -0.008985
# Part 1-2     0.171346 -0.040490 -0.000663    -0.000467  1.000000  0.695518
# Crm Cd      -0.049367  0.004699 -0.009071    -0.008985  0.695518  1.000000
# Mocodes      0.074359 -0.027978  0.035694     0.035924  0.162298  0.169301
# Vict Age     0.044727 -0.027104  0.014505     0.014312  0.182435 -0.023423
# Premis Cd    0.188086 -0.074906  0.007283     0.006894  0.279233  0.116753
# Crm Cd 1    -0.049480  0.004734 -0.009194    -0.009097  0.695870  0.998911
# Crm Cd 2    -0.038587  0.021322 -0.019791    -0.019963  0.052051  0.021776
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualisasi matriks korelasi
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Matriks Korelasi')
plt.show()

# %%
# Statistik deskriptif untuk kolom 'DR_NO'
print("\nStatistik Deskriptif untuk Kolom 'DR_NO':")
print(df['DR_NO'].describe())
# Out:
# Statistik Deskriptif untuk Kolom 'DR_NO':
# count    3.273900e+04
# mean     2.026426e+08
# std      5.682336e+06
# min      1.903265e+08
# 25%      2.006132e+08
# 50%      2.012140e+08
# 75%      2.018046e+08
# max      2.420047e+08
# Name: DR_NO, dtype: float64

# %%
# Mengubah kolom tanggal menjadi tipe datetime
df['Date Rptd'] = pd.to_datetime(df['Date Rptd'], errors='coerce')
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'], errors='coerce')

# Statistik deskriptif untuk kolom tanggal
print("\nStatistik Deskriptif untuk Kolom 'Date Rptd':")
print(df['Date Rptd'].describe())

print("\nStatistik Deskriptif untuk Kolom 'DATE OCC':")
print(df['DATE OCC'].describe())
# Out:
# Statistik Deskriptif untuk Kolom 'Date Rptd':
# count                            32739
# mean     2020-08-19 16:21:35.775680512
# min                2020-01-01 00:00:00
# 25%                2020-04-10 00:00:00
# 50%                2020-07-15 00:00:00
# 75%                2020-10-21 00:00:00
# max                2024-01-23 00:00:00
# Name: Date Rptd, dtype: object
#
# Statistik Deskriptif untuk Kolom 'DATE OCC':
# count                            32739
# mean     2020-06-27 13:18:21.475304960
# min                2020-01-01 00:00:00
# 25%                2020-03-27 00:00:00
# 50%                2020-06-26 00:00:00
# 75%                2020-09-27 00:00:00
# max                2020-12-31 00:00:00
# Name: DATE OCC, dtype: object

# %%
import matplotlib.pyplot as plt

# Histogram untuk kolom 'Date Rptd'
plt.figure(figsize=(12, 6))
df['Date Rptd'].dropna().hist(bins=30)
plt.title('Distribusi Tanggal Pelaporan')
plt.xlabel('Tanggal')
plt.ylabel('Frekuensi')
plt.show()

# Histogram untuk kolom 'DATE OCC'
plt.figure(figsize=(12, 6))
df['DATE OCC'].dropna().hist(bins=30)
plt.title('Distribusi Tanggal Kejadian')
plt.xlabel('Tanggal')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Menampilkan nilai unik dan frekuensi untuk kolom 'Date Rptd'
print("\nFrekuensi Hari dalam Seminggu untuk 'Date Rptd':")
print(df['Date Rptd'].dt.day_name().value_counts())

# Menampilkan nilai unik dan frekuensi untuk kolom 'DATE OCC'
print("\nFrekuensi Hari dalam Seminggu untuk 'DATE OCC':")
print(df['DATE OCC'].dt.day_name().value_counts())
# Out:
# Frekuensi Hari dalam Seminggu untuk 'Date Rptd':
# Date Rptd
# Monday       5111
# Wednesday    5041
# Tuesday      4953
# Thursday     4841
# Friday       4584
# Saturday     4159
# Sunday       4050
# Name: count, dtype: int64
#
# Frekuensi Hari dalam Seminggu untuk 'DATE OCC':
# DATE OCC
# Wednesday    4863
# Friday       4790
# Saturday     4777
# Monday       4659
# Thursday     4620
# Tuesday      4530
# Sunday       4500
# Name: count, dtype: int64

# %%
# Menampilkan jumlah nilai yang hilang per kolom
print("\nJumlah nilai yang hilang per kolom:")
print(df[['DR_NO', 'Date Rptd', 'DATE OCC']].isnull().sum())
# Out:
# Jumlah nilai yang hilang per kolom:
# DR_NO        0
# Date Rptd    0
# DATE OCC     0
# dtype: int64

# %%
# Statistik deskriptif untuk kolom kategorikal
print("\nStatistik Deskriptif untuk Kolom Kategorikal:")
for col in ['AREA', 'AREA NAME', 'Rpt Dist No', 'Part 1-2', 'Crm Cd']:
    print(f"\nFrekuensi untuk kolom {col}:")
    print(df[col].value_counts())
# Out:
# Statistik Deskriptif untuk Kolom Kategorikal:
#
# Frekuensi untuk kolom AREA:
# AREA
# 12    2211
# 3     1892
# 1     1873
# 14    1829
# 18    1754
# 15    1697
# 13    1693
# 6     1631
# 7     1619
# 20    1612
# 8     1536
# 5     1452
# 2     1445
# 9     1440
# 11    1384
# 19    1356
# 10    1333
# 17    1298
# 21    1287
# 4     1211
# 16    1186
# Name: count, dtype: int64
#
# Frekuensi untuk kolom AREA NAME:
# AREA NAME
# 77th Street    2211
# Southwest      1892
# Central        1873
# Pacific        1829
# Southeast      1754
# N Hollywood    1697
# Newton         1693
# Hollywood      1631
# Wilshire       1619
# Olympic        1612
# West LA        1536
# Harbor         1452
# Rampart        1445
# Van Nuys       1440
# Northeast      1384
# Mission        1356
# West Valley    1333
# Devonshire     1298
# Topanga        1287
# Hollenbeck     1211
# Foothill       1186
# Name: count, dtype: int64
#
# Frekuensi untuk kolom Rpt Dist No:
# Rpt Dist No
# 162     160
# ...

# %%
# Mengubah kolom waktu menjadi tipe waktu
df['TIME OCC'] = pd.to_datetime(df['TIME OCC'], format='%H:%M:%S', errors='coerce').dt.time

# Statistik deskriptif untuk kolom waktu 'TIME OCC'
print("\nStatistik Deskriptif untuk Kolom 'TIME OCC':")
print(df['TIME OCC'].value_counts())
# Out:
# Statistik Deskriptif untuk Kolom 'TIME OCC':
# Series([], Name: count, dtype: int64)

# %%
import matplotlib.pyplot as plt

# Visualisasi distribusi untuk kolom 'AREA'
plt.figure(figsize=(12, 6))
df['AREA'].value_counts().plot(kind='bar')
plt.title('Distribusi AREA')
plt.xlabel('AREA')
plt.ylabel('Frekuensi')
plt.show()

# Visualisasi distribusi untuk kolom 'AREA NAME'
plt.figure(figsize=(12, 6))
df['AREA NAME'].value_counts().plot(kind='bar')
plt.title('Distribusi AREA NAME')
plt.xlabel('AREA NAME')
plt.ylabel('Frekuensi')
plt.show()

# Visualisasi distribusi untuk kolom 'Rpt Dist No'
plt.figure(figsize=(12, 6))
df['Rpt Dist No'].value_counts().plot(kind='bar')
plt.title('Distribusi Rpt Dist No')
plt.xlabel('Rpt Dist No')
plt.ylabel('Frekuensi')
plt.show()

# Visualisasi distribusi untuk kolom 'Part 1-2'
plt.figure(figsize=(12, 6))
df['Part 1-2'].value_counts().plot(kind='bar')
plt.title('Distribusi Part 1-2')
plt.xlabel('Part 1-2')
plt.ylabel('Frekuensi')
plt.show()

# Visualisasi distribusi untuk kolom 'Crm Cd'
plt.figure(figsize=(12, 6))
df['Crm Cd'].value_counts().plot(kind='bar')
plt.title('Distribusi Crm Cd')
plt.xlabel('Crm Cd')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Menampilkan jumlah nilai yang hilang per kolom
print("\nJumlah nilai yang hilang per kolom:")
print(df[['TIME OCC', 'AREA', 'AREA NAME', 'Rpt Dist No', 'Part 1-2', 'Crm Cd']].isnull().sum())
# Out:
# Jumlah nilai yang hilang per kolom:
# TIME OCC       32739
# AREA               0
# AREA NAME          0
# Rpt Dist No        0
# Part 1-2           0
# Crm Cd             0
# dtype: int64

# %%
# Imputasi dengan waktu default, misalnya 00:00:00
df['TIME OCC'].fillna(pd.to_datetime('00:00:00').time(), inplace=True)

# %%
# Mengisi dengan mode waktu
mode_time = df['TIME OCC'].mode()[0]
df['TIME OCC'].fillna(mode_time, inplace=True)

# %%
# Mengubah kolom ke format datetime dan mengisi missing values dengan interpolasi
df['TIME OCC'] = pd.to_datetime(df['TIME OCC'], format='%H:%M:%S', errors='coerce')
df['TIME OCC'] = df['TIME OCC'].interpolate(method='linear')
df['TIME OCC'] = df['TIME OCC'].dt.time

# %%
# Menampilkan jumlah nilai yang hilang per kolom setelah imputasi
print("\nJumlah nilai yang hilang per kolom setelah imputasi:")
print(df[['TIME OCC', 'AREA', 'AREA NAME', 'Rpt Dist No', 'Part 1-2', 'Crm Cd']].isnull().sum())
# Out:
# Jumlah nilai yang hilang per kolom setelah imputasi:
# TIME OCC       0
# AREA           0
# AREA NAME      0
# Rpt Dist No    0
# Part 1-2       0
# Crm Cd         0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Menghitung frekuensi masing-masing waktu dalam format string
time_counts = df['TIME OCC'].astype(str).value_counts()

# Visualisasi distribusi waktu
plt.figure(figsize=(14, 7))
time_counts.plot(kind='bar')
plt.title('Distribusi Waktu dalam Kolom TIME OCC')
plt.xlabel('Waktu')
plt.ylabel('Frekuensi')
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.show()

# %%
# Memeriksa tipe data setiap kolom
print("\nTipe Data untuk Setiap Kolom:")
print(df.dtypes)

# Jika kolom-kolom tertentu perlu diubah menjadi tipe data yang sesuai
# Misalnya, mengonversi kolom 'TIME OCC' ke format numerik jika diperlukan untuk modeling
df['TIME OCC'] = pd.to_datetime(df['TIME OCC'], format='%H:%M:%S').dt.hour * 60 + pd.to_datetime(df['TIME OCC'], format='%H:%M:%S').dt.minute

# Menampilkan beberapa baris pertama untuk memastikan perubahan
print("\nBeberapa Baris Pertama setelah Konversi:")
print(df.head())
# Out:
# Tipe Data untuk Setiap Kolom:
# DR_NO                      int64
# Date Rptd         datetime64[ns]
# DATE OCC          datetime64[ns]
# TIME OCC                  object
# AREA                       int64
# AREA NAME                 object
# Rpt Dist No                int64
# Part 1-2                   int64
# Crm Cd                     int64
# Crm Cd Desc               object
# Mocodes                  float64
# Vict Age                   int64
# Vict Sex                  object
# Vict Descent              object
# Premis Cd                float64
# Premis Desc               object
# Weapon Used Cd            object
# Weapon Desc               object
# Status                    object
# Status Desc               object
# Crm Cd 1                 float64
# Crm Cd 2                 float64
# Crm Cd 3                 float64
# Crm Cd 4                 float64
# LOCATION                  object
# Cross Street              object
# LAT                      float64
# ...

# %% [markdown]
# # Visualisasi

# %%
# Menghitung frekuensi dari setiap jenis kejahatan
crime_type_counts = df['Crm Cd Desc'].value_counts()

# Membuat bar plot untuk distribusi jenis kejahatan
plt.figure(figsize=(12, 6))
sns.barplot(x=crime_type_counts.index, y=crime_type_counts.values, palette='viridis')
plt.xticks(rotation=90)
plt.title('Distribusi Jenis Kejahatan')
plt.xlabel('Jenis Kejahatan')
plt.ylabel('Jumlah Kejadian')
plt.show()

# %%
# Membuat tabel pivot untuk jumlah kejahatan per wilayah
area_crime_pivot = df.pivot_table(index='AREA NAME', columns='Crm Cd Desc', values='DR_NO', aggfunc='count')

# Membuat heatmap untuk visualisasi kepadatan kejahatan di berbagai wilayah
plt.figure(figsize=(12, 8))
sns.heatmap(area_crime_pivot, cmap='coolwarm', linewidths=.5, annot=True, fmt=".0f")
plt.title('Peta Panas Kepadatan Kejahatan di Berbagai Wilayah')
plt.xlabel('Jenis Kejahatan')
plt.ylabel('Wilayah')
plt.show()

# %%
# Mengonversi kolom tanggal menjadi tipe datetime
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])

# Mengelompokkan data berdasarkan bulan
df['Month'] = df['DATE OCC'].dt.to_period('M')
monthly_crime = df['Month'].value_counts().sort_index()

# Membuat line plot untuk tren kejahatan dari waktu ke waktu
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_crime.index.astype(str), y=monthly_crime.values, marker='o')
plt.xticks(rotation=45)
plt.title('Tren Kejahatan dari Waktu ke Waktu')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Kejahatan')
plt.show()

# %%
# Menghitung persentase setiap jenis senjata
weapon_counts = df['Weapon Desc'].value_counts()

# Membuat diagram donat untuk penggunaan senjata
plt.figure(figsize=(8, 8))
plt.pie(weapon_counts, labels=weapon_counts.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))
plt.title('Distribusi Penggunaan Jenis Senjata dalam Kejahatan')
plt.show()

# %%
# Membuat histogram untuk distribusi usia korban
plt.figure(figsize=(10, 6))
sns.histplot(df['Vict Age'], bins=30, kde=True, color='teal')
plt.title('Distribusi Usia Korban Kejahatan')
plt.xlabel('Usia Korban')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Membuat box plot untuk jumlah kejahatan berdasarkan area
plt.figure(figsize=(12, 6))
sns.boxplot(x='AREA NAME', y='Vict Age', data=df, palette='Set3')
plt.xticks(rotation=90)
plt.title('Box Plot Usia Korban Berdasarkan Wilayah')
plt.xlabel('Wilayah')
plt.ylabel('Usia Korban')
plt.show()

# %%
# Membuat scatter plot untuk lokasi kejahatan berdasarkan koordinat
plt.figure(figsize=(12, 8))
sns.scatterplot(x='LON', y='LAT', data=df, hue='AREA NAME', palette='tab10', legend=False)
plt.title('Scatter Plot Lokasi Kejahatan Berdasarkan Koordinat')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Membuat violin plot untuk distribusi usia korban berdasarkan jenis kelamin
plt.figure(figsize=(8, 6))
sns.violinplot(x='Vict Sex', y='Vict Age', data=df, palette='pastel')
plt.title('Distribusi Usia Korban Berdasarkan Jenis Kelamin')
plt.xlabel('Jenis Kelamin')
plt.ylabel('Usia Korban')
plt.show()

# %%
# Membuat count plot untuk status kejahatan
plt.figure(figsize=(8, 6))
sns.countplot(x='Status Desc', data=df, palette='coolwarm')
plt.title('Jumlah Kejahatan Berdasarkan Status Penyelidikan')
plt.xlabel('Status Penyelidikan')
plt.ylabel('Jumlah Kejadian')
plt.xticks(rotation=45)
plt.show()
